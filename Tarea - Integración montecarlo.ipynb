# %% [markdown]
# # TAREA

# %% [markdown]
# ## Integración Montecarlo

# %% [markdown]
# 1. Realizar las siguientes integrales. Poner los resultados en una tabla cuyas filas correspondan a la cantidad de términos utilizados en la aproximación (usar 10, 100, 1000, 10000 y 100000 términos) y cuyas columnas correspondan a las funciones.
#     + $\int_{1}^{3} e^{x}\log(x)\text{d}x$.
#     + $\int_1^3 \sin(x)\ln(x) \text{d}x$

# %%
import numpy as np
import pandas  as pd 
import matplotlib.pyplot as plt
# %matplotlib inline



def f1(x):
    return  ((np.e**(x)) * (np.log10)) 

def f2(x):
    return (np.sin(x)) * (np.log10)


N = np.logspace(1, 5, 7)
a = 1
b = 3

tabla = pd.DataFrame(columns = ["Aproximacion1", "Error1","Aproximacion2", "Error2", "Aproximacion3", "Error3" ], index = N)


def montecarlo(f, N, a , b) :
    u = np.random.uniform(a, b, N)
    media = np.mean(f(u))
    return media*(b-a)

for i in N :
    aproximacion = montecarlo(f1, int(i), a, b)
    tabla.loc[i, "Aproximacion1"] = aproximacion
    tabla.loc[i, "Error1"] = abs( - aproximacion)

for i in N :
    aproximacion = montecarlo(f2, int(i), a, b)
    tabla.loc[i, "Aproximacion2"] = aproximacion
    tabla.loc[i, "Error2"] = abs( - aproximacion)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 28
#      25     return media*(b-a)
#      27 for i in N :
# ---> 28     aproximacion = montecarlo(f1, int(i), a, b)
#      29     tabla.loc[i, "Aproximacion1"] = aproximacion
#      30     tabla.loc[i, "Error1"] = abs( - aproximacion)
#
# Cell In[77], line 24, in montecarlo(f, N, a, b)
#      22 def montecarlo(f, N, a , b) :
#      23     u = np.random.uniform(a, b, N)
# ---> 24     media = np.mean(f(u))
#      25     return media*(b-a)
#
# Cell In[77], line 9, in f1(x)
#       8 def f1(x):
# ----> 9     return  ((np.e**(x)) * (np.log10))
#
# TypeError: unsupported operand type(s) for *: 'float' and 'numpy.ufunc'

# %% [markdown]
# 2. Aproximar el área de la región descrita por
#
# $$x^2+2y^2\leq-2x+8y-7$$
#
# Poner los resultados en una tabla cuyas filas correspondan a la cantidad de términos utilizados en la aproximación (usar 10, 100, 1000, 10000 y 100000 términos) y en las columnas el valor de aproximación y el error relativo.
#
# Definir unos límites adecuados $a_1$, $b_1$, $a_2$ y $b_2$, para la región $R=\left[a_1,b_1\right]\times\left[a_2,b_2\right]$

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


def funcion(x,y):
    return ((x**2) + (2*(y**2)) <= (-2*x) + (8*y) - 7)

def montecarlo(region,xa, xb, ya, yb, N):
    x = np.random.uniform(xa, xb, N)
    y = np.random.uniform(xa, xb, N)
    B = region(x,y)
    AR =(xb-xa)*(yb-ya)
    return np.mean(B)*AR

montecarlo(fulanito, -5,5,-5,5,500)
# Out:
# 4.8

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x= np.random.uniform( -3.5,1,100)
y= np.random.uniform( 1,3 ,100)

X, Y = np.meshgrid(x, y) 
plt.figure()
plt.scatter(X, Y, c=funcion(X, Y))

# %%
import pandas as pd 

N = np.logspace(1, 5, 5)

tabla = pd.DataFrame(columns = ["Aproximación"], index = N)

for i in N :
    aproximacion = montecarlo(funcion, -5,5, -5,5, int(i))
    tabla.loc[i, "Aproximación"] = aproximacion   
    
tabla
# Out:
#          Aproximación
# 10.0             10.0
# 100.0             5.0
# 1000.0            4.7
# 10000.0          4.39
# 100000.0        4.393

# %% [markdown]
# 3. Describe 3 casos de uso de integración Montecarlo en tu ingeniería.

# %% [markdown]
# 1. Momento flector de una viga

# %% [markdown]
# 2. Desplazamiento, aceleración y velocidad de un cuerpo

# %% [markdown]
# 3.
